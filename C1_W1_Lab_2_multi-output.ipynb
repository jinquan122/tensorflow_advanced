# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 976us/sample - loss: 201.7351 - y1_output_loss: 98.7058 - y2_output_loss: 101.8661 - y1_output_root_mean_squared_error: 9.9539 - y2_output_root_mean_squared_error: 10.1319 - val_loss: 44.0586 - val_y1_output_loss: 20.2334 - val_y2_output_loss: 25.9733 - val_y1_output_root_mean_squared_error: 4.3955 - val_y2_output_root_mean_squared_error: 4.9737
# Epoch 2/500
# 614/614 [==============================] - 0s 162us/sample - loss: 37.3875 - y1_output_loss: 13.6568 - y2_output_loss: 23.6139 - y1_output_root_mean_squared_error: 3.7007 - y2_output_root_mean_squared_error: 4.8674 - val_loss: 24.5430 - val_y1_output_loss: 9.7360 - val_y2_output_loss: 15.6152 - val_y1_output_root_mean_squared_error: 3.0054 - val_y2_output_root_mean_squared_error: 3.9384
# Epoch 3/500
# 614/614 [==============================] - 0s 139us/sample - loss: 28.2689 - y1_output_loss: 10.3102 - y2_output_loss: 18.2480 - y1_output_root_mean_squared_error: 3.1952 - y2_output_root_mean_squared_error: 4.2497 - val_loss: 66.6187 - val_y1_output_loss: 17.9863 - val_y2_output_loss: 49.5936 - val_y1_output_root_mean_squared_error: 4.2423 - val_y2_output_root_mean_squared_error: 6.9729
# Epoch 4/500
# 614/614 [==============================] - 0s 138us/sample - loss: 27.2199 - y1_output_loss: 9.3560 - y2_output_loss: 17.7026 - y1_output_root_mean_squared_error: 3.0667 - y2_output_root_mean_squared_error: 4.2208 - val_loss: 18.9759 - val_y1_output_loss: 9.5490 - val_y2_output_loss: 9.5529 - val_y1_output_root_mean_squared_error: 3.0393 - val_y2_output_root_mean_squared_error: 3.1207
# Epoch 5/500
# 614/614 [==============================] - 0s 133us/sample - loss: 23.6308 - y1_output_loss: 9.1509 - y2_output_loss: 15.4940 - y1_output_root_mean_squared_error: 3.0094 - y2_output_root_mean_squared_error: 3.8176 - val_loss: 140.0274 - val_y1_output_loss: 40.8029 - val_y2_output_loss: 104.5573 - val_y1_output_root_mean_squared_error: 6.1884 - val_y2_output_root_mean_squared_error: 10.0862
# Epoch 6/500
# 614/614 [==============================] - 0s 136us/sample - loss: 27.5477 - y1_output_loss: 10.0570 - y2_output_loss: 17.5252 - y1_output_root_mean_squared_error: 3.1533 - y2_output_root_mean_squared_error: 4.1958 - val_loss: 49.1611 - val_y1_output_loss: 15.8872 - val_y2_output_loss: 33.4682 - val_y1_output_root_mean_squared_error: 4.0081 - val_y2_output_root_mean_squared_error: 5.7529
# Epoch 7/500
# 614/614 [==============================] - 0s 133us/sample - loss: 21.0749 - y1_output_loss: 8.3656 - y2_output_loss: 12.5562 - y1_output_root_mean_squared_error: 2.9054 - y2_output_root_mean_squared_error: 3.5543 - val_loss: 20.4208 - val_y1_output_loss: 9.5633 - val_y2_output_loss: 10.6337 - val_y1_output_root_mean_squared_error: 3.0877 - val_y2_output_root_mean_squared_error: 3.2995
# Epoch 8/500
# 614/614 [==============================] - 0s 148us/sample - loss: 22.1854 - y1_output_loss: 8.3179 - y2_output_loss: 13.9825 - y1_output_root_mean_squared_error: 2.8822 - y2_output_root_mean_squared_error: 3.7254 - val_loss: 32.9223 - val_y1_output_loss: 12.5775 - val_y2_output_loss: 20.1952 - val_y1_output_root_mean_squared_error: 3.5566 - val_y2_output_root_mean_squared_error: 4.5025
# Epoch 9/500
# 614/614 [==============================] - 0s 131us/sample - loss: 22.5303 - y1_output_loss: 8.2950 - y2_output_loss: 14.2500 - y1_output_root_mean_squared_error: 2.8869 - y2_output_root_mean_squared_error: 3.7678 - val_loss: 25.3996 - val_y1_output_loss: 10.0935 - val_y2_output_loss: 15.9684 - val_y1_output_root_mean_squared_error: 3.0882 - val_y2_output_root_mean_squared_error: 3.9828
# Epoch 10/500
# 614/614 [==============================] - 0s 137us/sample - loss: 19.9614 - y1_output_loss: 7.6169 - y2_output_loss: 12.5453 - y1_output_root_mean_squared_error: 2.7372 - y2_output_root_mean_squared_error: 3.5312 - val_loss: 31.4759 - val_y1_output_loss: 9.5366 - val_y2_output_loss: 22.2798 - val_y1_output_root_mean_squared_error: 3.0384 - val_y2_output_root_mean_squared_error: 4.7164
# Epoch 11/500
# 614/614 [==============================] - 0s 140us/sample - loss: 18.0343 - y1_output_loss: 6.8716 - y2_output_loss: 11.1840 - y1_output_root_mean_squared_error: 2.6124 - y2_output_root_mean_squared_error: 3.3481 - val_loss: 20.6538 - val_y1_output_loss: 8.1200 - val_y2_output_loss: 12.4252 - val_y1_output_root_mean_squared_error: 2.8313 - val_y2_output_root_mean_squared_error: 3.5549
# Epoch 12/500
# 614/614 [==============================] - 0s 143us/sample - loss: 20.9442 - y1_output_loss: 7.5036 - y2_output_loss: 13.5933 - y1_output_root_mean_squared_error: 2.7473 - y2_output_root_mean_squared_error: 3.6601 - val_loss: 62.0043 - val_y1_output_loss: 15.7427 - val_y2_output_loss: 46.5828 - val_y1_output_root_mean_squared_error: 3.9839 - val_y2_output_root_mean_squared_error: 6.7921
# Epoch 13/500
# 614/614 [==============================] - 0s 138us/sample - loss: 19.6005 - y1_output_loss: 7.5914 - y2_output_loss: 11.8381 - y1_output_root_mean_squared_error: 2.7683 - y2_output_root_mean_squared_error: 3.4550 - val_loss: 18.4396 - val_y1_output_loss: 8.8725 - val_y2_output_loss: 9.4789 - val_y1_output_root_mean_squared_error: 2.9571 - val_y2_output_root_mean_squared_error: 3.1138
# Epoch 14/500
# 614/614 [==============================] - 0s 132us/sample - loss: 20.5858 - y1_output_loss: 7.1970 - y2_output_loss: 13.2697 - y1_output_root_mean_squared_error: 2.6938 - y2_output_root_mean_squared_error: 3.6509 - val_loss: 20.8760 - val_y1_output_loss: 8.9768 - val_y2_output_loss: 11.8493 - val_y1_output_root_mean_squared_error: 2.9865 - val_y2_output_root_mean_squared_error: 3.4579
# Epoch 15/500
# 614/614 [==============================] - 0s 132us/sample - loss: 16.9137 - y1_output_loss: 6.3392 - y2_output_loss: 10.6505 - y1_output_root_mean_squared_error: 2.5201 - y2_output_root_mean_squared_error: 3.2500 - val_loss: 37.0671 - val_y1_output_loss: 11.6743 - val_y2_output_loss: 25.9390 - val_y1_output_root_mean_squared_error: 3.4253 - val_y2_output_root_mean_squared_error: 5.0333
# Epoch 16/500
# 614/614 [==============================] - 0s 130us/sample - loss: 17.4689 - y1_output_loss: 6.4071 - y2_output_loss: 11.2024 - y1_output_root_mean_squared_error: 2.5184 - y2_output_root_mean_squared_error: 3.3357 - val_loss: 37.5628 - val_y1_output_loss: 12.6905 - val_y2_output_loss: 26.0883 - val_y1_output_root_mean_squared_error: 3.4481 - val_y2_output_root_mean_squared_error: 5.0669
# Epoch 17/500
# 614/614 [==============================] - 0s 142us/sample - loss: 14.7062 - y1_output_loss: 5.7240 - y2_output_loss: 8.8968 - y1_output_root_mean_squared_error: 2.4025 - y2_output_root_mean_squared_error: 2.9890 - val_loss: 14.8767 - val_y1_output_loss: 6.9075 - val_y2_output_loss: 7.8378 - val_y1_output_root_mean_squared_error: 2.6166 - val_y2_output_root_mean_squared_error: 2.8337
# Epoch 18/500
# 614/614 [==============================] - 0s 130us/sample - loss: 16.4147 - y1_output_loss: 5.8404 - y2_output_loss: 10.4836 - y1_output_root_mean_squared_error: 2.4197 - y2_output_root_mean_squared_error: 3.2496 - val_loss: 16.8996 - val_y1_output_loss: 8.5431 - val_y2_output_loss: 8.6700 - val_y1_output_root_mean_squared_error: 2.8456 - val_y2_output_root_mean_squared_error: 2.9669
# Epoch 19/500
# 614/614 [==============================] - 0s 130us/sample - loss: 15.2316 - y1_output_loss: 5.6579 - y2_output_loss: 9.4354 - y1_output_root_mean_squared_error: 2.3891 - y2_output_root_mean_squared_error: 3.0861 - val_loss: 13.9686 - val_y1_output_loss: 6.5500 - val_y2_output_loss: 7.2767 - val_y1_output_root_mean_squared_error: 2.5485 - val_y2_output_root_mean_squared_error: 2.7338
# Epoch 20/500
# 614/614 [==============================] - 0s 131us/sample - loss: 13.5127 - y1_output_loss: 5.1491 - y2_output_loss: 8.2391 - y1_output_root_mean_squared_error: 2.2793 - y2_output_root_mean_squared_error: 2.8840 - val_loss: 14.7775 - val_y1_output_loss: 7.0357 - val_y2_output_loss: 7.4786 - val_y1_output_root_mean_squared_error: 2.6668 - val_y2_output_root_mean_squared_error: 2.7687
# Epoch 21/500
# 614/614 [==============================] - 0s 130us/sample - loss: 13.0288 - y1_output_loss: 4.8560 - y2_output_loss: 8.0545 - y1_output_root_mean_squared_error: 2.2138 - y2_output_root_mean_squared_error: 2.8509 - val_loss: 13.3151 - val_y1_output_loss: 6.5392 - val_y2_output_loss: 6.7799 - val_y1_output_root_mean_squared_error: 2.5405 - val_y2_output_root_mean_squared_error: 2.6193
# Epoch 22/500
# 614/614 [==============================] - 0s 142us/sample - loss: 16.0870 - y1_output_loss: 5.5960 - y2_output_loss: 10.5901 - y1_output_root_mean_squared_error: 2.3528 - y2_output_root_mean_squared_error: 3.2483 - val_loss: 13.6509 - val_y1_output_loss: 6.5692 - val_y2_output_loss: 7.0759 - val_y1_output_root_mean_squared_error: 2.5385 - val_y2_output_root_mean_squared_error: 2.6846
# Epoch 23/500
# 614/614 [==============================] - 0s 137us/sample - loss: 18.4447 - y1_output_loss: 5.9043 - y2_output_loss: 12.4444 - y1_output_root_mean_squared_error: 2.4302 - y2_output_root_mean_squared_error: 3.5410 - val_loss: 13.6886 - val_y1_output_loss: 6.3700 - val_y2_output_loss: 7.0877 - val_y1_output_root_mean_squared_error: 2.5479 - val_y2_output_root_mean_squared_error: 2.6827
# Epoch 24/500
# 614/614 [==============================] - 0s 137us/sample - loss: 12.2294 - y1_output_loss: 4.6041 - y2_output_loss: 7.7752 - y1_output_root_mean_squared_error: 2.1259 - y2_output_root_mean_squared_error: 2.7767 - val_loss: 24.3239 - val_y1_output_loss: 8.1045 - val_y2_output_loss: 16.5932 - val_y1_output_root_mean_squared_error: 2.7887 - val_y2_output_root_mean_squared_error: 4.0678
# Epoch 25/500
# 614/614 [==============================] - 0s 136us/sample - loss: 12.6823 - y1_output_loss: 4.4052 - y2_output_loss: 8.2412 - y1_output_root_mean_squared_error: 2.1013 - y2_output_root_mean_squared_error: 2.8752 - val_loss: 16.2287 - val_y1_output_loss: 6.4085 - val_y2_output_loss: 9.6619 - val_y1_output_root_mean_squared_error: 2.5456 - val_y2_output_root_mean_squared_error: 3.1223
# Epoch 26/500
# 614/614 [==============================] - 0s 138us/sample - loss: 11.6722 - y1_output_loss: 4.1765 - y2_output_loss: 7.3882 - y1_output_root_mean_squared_error: 2.0526 - y2_output_root_mean_squared_error: 2.7311 - val_loss: 11.7184 - val_y1_output_loss: 5.6855 - val_y2_output_loss: 5.8813 - val_y1_output_root_mean_squared_error: 2.3965 - val_y2_output_root_mean_squared_error: 2.4444
# Epoch 27/500
# 614/614 [==============================] - 0s 137us/sample - loss: 11.8978 - y1_output_loss: 4.0136 - y2_output_loss: 7.7825 - y1_output_root_mean_squared_error: 2.0114 - y2_output_root_mean_squared_error: 2.8022 - val_loss: 11.6481 - val_y1_output_loss: 5.4576 - val_y2_output_loss: 5.9857 - val_y1_output_root_mean_squared_error: 2.3390 - val_y2_output_root_mean_squared_error: 2.4854
# Epoch 28/500
# 614/614 [==============================] - 0s 135us/sample - loss: 11.3659 - y1_output_loss: 4.1891 - y2_output_loss: 7.3717 - y1_output_root_mean_squared_error: 2.0181 - y2_output_root_mean_squared_error: 2.7006 - val_loss: 16.5319 - val_y1_output_loss: 6.5808 - val_y2_output_loss: 9.9102 - val_y1_output_root_mean_squared_error: 2.5378 - val_y2_output_root_mean_squared_error: 3.1767
# Epoch 29/500
# 614/614 [==============================] - 0s 130us/sample - loss: 10.9266 - y1_output_loss: 4.0260 - y2_output_loss: 6.8351 - y1_output_root_mean_squared_error: 2.0106 - y2_output_root_mean_squared_error: 2.6237 - val_loss: 12.7938 - val_y1_output_loss: 5.0187 - val_y2_output_loss: 7.7140 - val_y1_output_root_mean_squared_error: 2.2518 - val_y2_output_root_mean_squared_error: 2.7791
# Epoch 30/500
# 614/614 [==============================] - 0s 132us/sample - loss: 13.2541 - y1_output_loss: 4.1935 - y2_output_loss: 9.0258 - y1_output_root_mean_squared_error: 2.0486 - y2_output_root_mean_squared_error: 3.0096 - val_loss: 19.8340 - val_y1_output_loss: 9.3386 - val_y2_output_loss: 10.3853 - val_y1_output_root_mean_squared_error: 3.0877 - val_y2_output_root_mean_squared_error: 3.2094
# Epoch 31/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.6889 - y1_output_loss: 4.1295 - y2_output_loss: 8.7219 - y1_output_root_mean_squared_error: 2.0163 - y2_output_root_mean_squared_error: 2.9366 - val_loss: 17.9024 - val_y1_output_loss: 6.8932 - val_y2_output_loss: 11.1249 - val_y1_output_root_mean_squared_error: 2.5868 - val_y2_output_root_mean_squared_error: 3.3482
# Epoch 32/500
# 614/614 [==============================] - 0s 130us/sample - loss: 13.6932 - y1_output_loss: 4.0796 - y2_output_loss: 9.5137 - y1_output_root_mean_squared_error: 2.0257 - y2_output_root_mean_squared_error: 3.0968 - val_loss: 12.2704 - val_y1_output_loss: 4.6766 - val_y2_output_loss: 7.6276 - val_y1_output_root_mean_squared_error: 2.1904 - val_y2_output_root_mean_squared_error: 2.7336
# Epoch 33/500
# 614/614 [==============================] - 0s 132us/sample - loss: 11.7391 - y1_output_loss: 3.9667 - y2_output_loss: 7.9178 - y1_output_root_mean_squared_error: 1.9904 - y2_output_root_mean_squared_error: 2.7888 - val_loss: 16.4982 - val_y1_output_loss: 5.0380 - val_y2_output_loss: 11.5072 - val_y1_output_root_mean_squared_error: 2.2639 - val_y2_output_root_mean_squared_error: 3.3724
# Epoch 34/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.7946 - y1_output_loss: 3.3183 - y2_output_loss: 6.4512 - y1_output_root_mean_squared_error: 1.8131 - y2_output_root_mean_squared_error: 2.5510 - val_loss: 13.4545 - val_y1_output_loss: 6.0382 - val_y2_output_loss: 7.5095 - val_y1_output_root_mean_squared_error: 2.4815 - val_y2_output_root_mean_squared_error: 2.7012
# Epoch 35/500
# 614/614 [==============================] - 0s 140us/sample - loss: 12.0840 - y1_output_loss: 3.7622 - y2_output_loss: 8.2350 - y1_output_root_mean_squared_error: 1.9432 - y2_output_root_mean_squared_error: 2.8824 - val_loss: 9.9707 - val_y1_output_loss: 3.9888 - val_y2_output_loss: 5.8899 - val_y1_output_root_mean_squared_error: 1.9934 - val_y2_output_root_mean_squared_error: 2.4489
# Epoch 36/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.4242 - y1_output_loss: 3.3322 - y2_output_loss: 7.6829 - y1_output_root_mean_squared_error: 1.7937 - y2_output_root_mean_squared_error: 2.6845 - val_loss: 40.3535 - val_y1_output_loss: 11.5918 - val_y2_output_loss: 28.9632 - val_y1_output_root_mean_squared_error: 3.4296 - val_y2_output_root_mean_squared_error: 5.3471
# Epoch 37/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.5775 - y1_output_loss: 2.9183 - y2_output_loss: 5.5818 - y1_output_root_mean_squared_error: 1.7158 - y2_output_root_mean_squared_error: 2.3735 - val_loss: 8.6010 - val_y1_output_loss: 3.5265 - val_y2_output_loss: 5.1649 - val_y1_output_root_mean_squared_error: 1.8850 - val_y2_output_root_mean_squared_error: 2.2468
# Epoch 38/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.5158 - y1_output_loss: 2.6815 - y2_output_loss: 4.8743 - y1_output_root_mean_squared_error: 1.6334 - y2_output_root_mean_squared_error: 2.2018 - val_loss: 11.4626 - val_y1_output_loss: 4.4064 - val_y2_output_loss: 7.1057 - val_y1_output_root_mean_squared_error: 2.1266 - val_y2_output_root_mean_squared_error: 2.6345
# Epoch 39/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.3652 - y1_output_loss: 2.8591 - y2_output_loss: 5.4645 - y1_output_root_mean_squared_error: 1.6969 - y2_output_root_mean_squared_error: 2.3422 - val_loss: 8.6854 - val_y1_output_loss: 3.5393 - val_y2_output_loss: 5.3317 - val_y1_output_root_mean_squared_error: 1.8771 - val_y2_output_root_mean_squared_error: 2.2720
# Epoch 40/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.2470 - y1_output_loss: 2.6938 - y2_output_loss: 5.7762 - y1_output_root_mean_squared_error: 1.6256 - y2_output_root_mean_squared_error: 2.3673 - val_loss: 49.8086 - val_y1_output_loss: 10.8053 - val_y2_output_loss: 41.1319 - val_y1_output_root_mean_squared_error: 3.2758 - val_y2_output_root_mean_squared_error: 6.2512
# Epoch 41/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.0302 - y1_output_loss: 2.8452 - y2_output_loss: 6.1167 - y1_output_root_mean_squared_error: 1.6931 - y2_output_root_mean_squared_error: 2.4827 - val_loss: 9.8721 - val_y1_output_loss: 3.7499 - val_y2_output_loss: 6.0653 - val_y1_output_root_mean_squared_error: 1.9610 - val_y2_output_root_mean_squared_error: 2.4549
# Epoch 42/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.7507 - y1_output_loss: 2.5167 - y2_output_loss: 5.2099 - y1_output_root_mean_squared_error: 1.5881 - y2_output_root_mean_squared_error: 2.2866 - val_loss: 10.8518 - val_y1_output_loss: 5.0585 - val_y2_output_loss: 5.8218 - val_y1_output_root_mean_squared_error: 2.2448 - val_y2_output_root_mean_squared_error: 2.4110
# Epoch 43/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.2861 - y1_output_loss: 2.6595 - y2_output_loss: 5.6802 - y1_output_root_mean_squared_error: 1.6056 - y2_output_root_mean_squared_error: 2.3891 - val_loss: 15.2400 - val_y1_output_loss: 5.9865 - val_y2_output_loss: 9.2416 - val_y1_output_root_mean_squared_error: 2.4149 - val_y2_output_root_mean_squared_error: 3.0673
# Epoch 44/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.8368 - y1_output_loss: 2.3686 - y2_output_loss: 5.4827 - y1_output_root_mean_squared_error: 1.5437 - y2_output_root_mean_squared_error: 2.3353 - val_loss: 9.5001 - val_y1_output_loss: 3.0099 - val_y2_output_loss: 6.5975 - val_y1_output_root_mean_squared_error: 1.7665 - val_y2_output_root_mean_squared_error: 2.5258
# Epoch 45/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.3610 - y1_output_loss: 2.7992 - y2_output_loss: 6.6308 - y1_output_root_mean_squared_error: 1.6728 - y2_output_root_mean_squared_error: 2.5618 - val_loss: 22.6622 - val_y1_output_loss: 6.9070 - val_y2_output_loss: 16.3527 - val_y1_output_root_mean_squared_error: 2.6417 - val_y2_output_root_mean_squared_error: 3.9603
# Epoch 46/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.2827 - y1_output_loss: 2.3686 - y2_output_loss: 4.8464 - y1_output_root_mean_squared_error: 1.5461 - y2_output_root_mean_squared_error: 2.2118 - val_loss: 7.6709 - val_y1_output_loss: 3.3674 - val_y2_output_loss: 4.2921 - val_y1_output_root_mean_squared_error: 1.8360 - val_y2_output_root_mean_squared_error: 2.0736
# Epoch 47/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.1599 - y1_output_loss: 2.5594 - y2_output_loss: 6.6066 - y1_output_root_mean_squared_error: 1.6035 - y2_output_root_mean_squared_error: 2.5669 - val_loss: 11.1912 - val_y1_output_loss: 3.8976 - val_y2_output_loss: 7.4324 - val_y1_output_root_mean_squared_error: 2.0036 - val_y2_output_root_mean_squared_error: 2.6789
# Epoch 48/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.8819 - y1_output_loss: 2.3960 - y2_output_loss: 5.4526 - y1_output_root_mean_squared_error: 1.5516 - y2_output_root_mean_squared_error: 2.3398 - val_loss: 7.9434 - val_y1_output_loss: 3.4904 - val_y2_output_loss: 4.2949 - val_y1_output_root_mean_squared_error: 1.9021 - val_y2_output_root_mean_squared_error: 2.0798
# Epoch 49/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.4396 - y1_output_loss: 2.5410 - y2_output_loss: 5.8644 - y1_output_root_mean_squared_error: 1.5984 - y2_output_root_mean_squared_error: 2.4258 - val_loss: 16.0897 - val_y1_output_loss: 4.5211 - val_y2_output_loss: 12.1352 - val_y1_output_root_mean_squared_error: 2.1408 - val_y2_output_root_mean_squared_error: 3.3922
# Epoch 50/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.1782 - y1_output_loss: 2.1150 - y2_output_loss: 5.0021 - y1_output_root_mean_squared_error: 1.4604 - y2_output_root_mean_squared_error: 2.2462 - val_loss: 6.4647 - val_y1_output_loss: 2.4960 - val_y2_output_loss: 3.8749 - val_y1_output_root_mean_squared_error: 1.6001 - val_y2_output_root_mean_squared_error: 1.9760
# Epoch 51/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.2053 - y1_output_loss: 2.3822 - y2_output_loss: 5.7457 - y1_output_root_mean_squared_error: 1.5507 - y2_output_root_mean_squared_error: 2.4085 - val_loss: 5.8625 - val_y1_output_loss: 2.3639 - val_y2_output_loss: 3.4609 - val_y1_output_root_mean_squared_error: 1.5529 - val_y2_output_root_mean_squared_error: 1.8577
# Epoch 52/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.0937 - y1_output_loss: 1.9378 - y2_output_loss: 4.1059 - y1_output_root_mean_squared_error: 1.3977 - y2_output_root_mean_squared_error: 2.0347 - val_loss: 6.3483 - val_y1_output_loss: 2.4275 - val_y2_output_loss: 3.9574 - val_y1_output_root_mean_squared_error: 1.5713 - val_y2_output_root_mean_squared_error: 1.9696
# Epoch 53/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.2707 - y1_output_loss: 1.9757 - y2_output_loss: 4.3488 - y1_output_root_mean_squared_error: 1.3925 - y2_output_root_mean_squared_error: 2.0813 - val_loss: 9.1697 - val_y1_output_loss: 3.4369 - val_y2_output_loss: 5.6271 - val_y1_output_root_mean_squared_error: 1.8428 - val_y2_output_root_mean_squared_error: 2.4029
# Epoch 54/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.3897 - y1_output_loss: 1.9664 - y2_output_loss: 4.3755 - y1_output_root_mean_squared_error: 1.4053 - y2_output_root_mean_squared_error: 2.1012 - val_loss: 5.8435 - val_y1_output_loss: 2.1255 - val_y2_output_loss: 3.6117 - val_y1_output_root_mean_squared_error: 1.4797 - val_y2_output_root_mean_squared_error: 1.9115
# Epoch 55/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.0861 - y1_output_loss: 2.2930 - y2_output_loss: 5.7317 - y1_output_root_mean_squared_error: 1.5206 - y2_output_root_mean_squared_error: 2.4029 - val_loss: 8.5634 - val_y1_output_loss: 3.1070 - val_y2_output_loss: 5.7383 - val_y1_output_root_mean_squared_error: 1.7657 - val_y2_output_root_mean_squared_error: 2.3336
# Epoch 56/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.1167 - y1_output_loss: 2.0103 - y2_output_loss: 5.3593 - y1_output_root_mean_squared_error: 1.4132 - y2_output_root_mean_squared_error: 2.2627 - val_loss: 38.5634 - val_y1_output_loss: 10.1112 - val_y2_output_loss: 29.9874 - val_y1_output_root_mean_squared_error: 3.0696 - val_y2_output_root_mean_squared_error: 5.3982
# Epoch 57/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.9822 - y1_output_loss: 2.2822 - y2_output_loss: 4.6489 - y1_output_root_mean_squared_error: 1.5176 - y2_output_root_mean_squared_error: 2.1631 - val_loss: 8.9586 - val_y1_output_loss: 2.8084 - val_y2_output_loss: 6.3556 - val_y1_output_root_mean_squared_error: 1.7020 - val_y2_output_root_mean_squared_error: 2.4620
# Epoch 58/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.4758 - y1_output_loss: 1.7041 - y2_output_loss: 3.7898 - y1_output_root_mean_squared_error: 1.3013 - y2_output_root_mean_squared_error: 1.9449 - val_loss: 12.0457 - val_y1_output_loss: 5.2403 - val_y2_output_loss: 6.9925 - val_y1_output_root_mean_squared_error: 2.2524 - val_y2_output_root_mean_squared_error: 2.6405
# Epoch 59/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.4078 - y1_output_loss: 2.2145 - y2_output_loss: 5.1269 - y1_output_root_mean_squared_error: 1.4945 - y2_output_root_mean_squared_error: 2.2747 - val_loss: 5.9424 - val_y1_output_loss: 2.3477 - val_y2_output_loss: 3.5271 - val_y1_output_root_mean_squared_error: 1.5392 - val_y2_output_root_mean_squared_error: 1.8903
# Epoch 60/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.7178 - y1_output_loss: 1.7602 - y2_output_loss: 3.9926 - y1_output_root_mean_squared_error: 1.3287 - y2_output_root_mean_squared_error: 1.9881 - val_loss: 8.8567 - val_y1_output_loss: 3.2535 - val_y2_output_loss: 5.8025 - val_y1_output_root_mean_squared_error: 1.8233 - val_y2_output_root_mean_squared_error: 2.3521
# Epoch 61/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.9553 - y1_output_loss: 1.6635 - y2_output_loss: 4.3195 - y1_output_root_mean_squared_error: 1.2725 - y2_output_root_mean_squared_error: 2.0823 - val_loss: 12.9882 - val_y1_output_loss: 5.0827 - val_y2_output_loss: 8.0716 - val_y1_output_root_mean_squared_error: 2.2150 - val_y2_output_root_mean_squared_error: 2.8429
# Epoch 62/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.2529 - y1_output_loss: 1.6454 - y2_output_loss: 3.6191 - y1_output_root_mean_squared_error: 1.2785 - y2_output_root_mean_squared_error: 1.9022 - val_loss: 5.8013 - val_y1_output_loss: 1.9088 - val_y2_output_loss: 4.0545 - val_y1_output_root_mean_squared_error: 1.3965 - val_y2_output_root_mean_squared_error: 1.9624
# Epoch 63/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.7225 - y1_output_loss: 1.7499 - y2_output_loss: 3.9775 - y1_output_root_mean_squared_error: 1.3168 - y2_output_root_mean_squared_error: 1.9972 - val_loss: 7.7864 - val_y1_output_loss: 3.3230 - val_y2_output_loss: 4.4422 - val_y1_output_root_mean_squared_error: 1.7996 - val_y2_output_root_mean_squared_error: 2.1326
# Epoch 64/500
# 614/614 [==============================] - 0s 135us/sample - loss: 9.4837 - y1_output_loss: 2.8492 - y2_output_loss: 6.5532 - y1_output_root_mean_squared_error: 1.6937 - y2_output_root_mean_squared_error: 2.5720 - val_loss: 4.8183 - val_y1_output_loss: 1.7448 - val_y2_output_loss: 3.0972 - val_y1_output_root_mean_squared_error: 1.3396 - val_y2_output_root_mean_squared_error: 1.7389
# Epoch 65/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.2103 - y1_output_loss: 1.8807 - y2_output_loss: 4.2775 - y1_output_root_mean_squared_error: 1.3773 - y2_output_root_mean_squared_error: 2.0769 - val_loss: 6.0538 - val_y1_output_loss: 2.2220 - val_y2_output_loss: 3.9536 - val_y1_output_root_mean_squared_error: 1.5154 - val_y2_output_root_mean_squared_error: 1.9384
# Epoch 66/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.7177 - y1_output_loss: 1.6777 - y2_output_loss: 4.0967 - y1_output_root_mean_squared_error: 1.2934 - y2_output_root_mean_squared_error: 2.0112 - val_loss: 5.6764 - val_y1_output_loss: 2.4596 - val_y2_output_loss: 3.2024 - val_y1_output_root_mean_squared_error: 1.5740 - val_y2_output_root_mean_squared_error: 1.7886
# Epoch 67/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.0212 - y1_output_loss: 1.4911 - y2_output_loss: 3.5565 - y1_output_root_mean_squared_error: 1.2251 - y2_output_root_mean_squared_error: 1.8763 - val_loss: 4.9873 - val_y1_output_loss: 2.2822 - val_y2_output_loss: 2.8329 - val_y1_output_root_mean_squared_error: 1.4988 - val_y2_output_root_mean_squared_error: 1.6555
# Epoch 68/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.1654 - y1_output_loss: 1.3877 - y2_output_loss: 3.7378 - y1_output_root_mean_squared_error: 1.1826 - y2_output_root_mean_squared_error: 1.9408 - val_loss: 5.0801 - val_y1_output_loss: 1.8734 - val_y2_output_loss: 3.3890 - val_y1_output_root_mean_squared_error: 1.3651 - val_y2_output_root_mean_squared_error: 1.7935
# Epoch 69/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.1384 - y1_output_loss: 1.3662 - y2_output_loss: 3.7499 - y1_output_root_mean_squared_error: 1.1731 - y2_output_root_mean_squared_error: 1.9396 - val_loss: 5.1443 - val_y1_output_loss: 1.6929 - val_y2_output_loss: 3.5812 - val_y1_output_root_mean_squared_error: 1.3209 - val_y2_output_root_mean_squared_error: 1.8438
# Epoch 70/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.3745 - y1_output_loss: 1.9061 - y2_output_loss: 4.6247 - y1_output_root_mean_squared_error: 1.3467 - y2_output_root_mean_squared_error: 2.1356 - val_loss: 15.7856 - val_y1_output_loss: 5.0890 - val_y2_output_loss: 10.6537 - val_y1_output_root_mean_squared_error: 2.2314 - val_y2_output_root_mean_squared_error: 3.2874
# Epoch 71/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.5595 - y1_output_loss: 1.7539 - y2_output_loss: 3.9147 - y1_output_root_mean_squared_error: 1.3128 - y2_output_root_mean_squared_error: 1.9586 - val_loss: 19.9246 - val_y1_output_loss: 7.7396 - val_y2_output_loss: 12.3817 - val_y1_output_root_mean_squared_error: 2.7446 - val_y2_output_root_mean_squared_error: 3.5202
# Epoch 72/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.5769 - y1_output_loss: 1.6262 - y2_output_loss: 3.9142 - y1_output_root_mean_squared_error: 1.2768 - y2_output_root_mean_squared_error: 1.9866 - val_loss: 6.2991 - val_y1_output_loss: 1.9485 - val_y2_output_loss: 4.8573 - val_y1_output_root_mean_squared_error: 1.3936 - val_y2_output_root_mean_squared_error: 2.0873
# Epoch 73/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.1899 - y1_output_loss: 2.0961 - y2_output_loss: 5.0530 - y1_output_root_mean_squared_error: 1.4532 - y2_output_root_mean_squared_error: 2.2534 - val_loss: 5.7190 - val_y1_output_loss: 1.5381 - val_y2_output_loss: 4.4992 - val_y1_output_root_mean_squared_error: 1.2506 - val_y2_output_root_mean_squared_error: 2.0384
# Epoch 74/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.7122 - y1_output_loss: 1.1109 - y2_output_loss: 2.5746 - y1_output_root_mean_squared_error: 1.0557 - y2_output_root_mean_squared_error: 1.6118 - val_loss: 3.5690 - val_y1_output_loss: 1.3063 - val_y2_output_loss: 2.3202 - val_y1_output_root_mean_squared_error: 1.1506 - val_y2_output_root_mean_squared_error: 1.4984
# Epoch 75/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.2342 - y1_output_loss: 1.0114 - y2_output_loss: 3.1934 - y1_output_root_mean_squared_error: 1.0091 - y2_output_root_mean_squared_error: 1.7933 - val_loss: 4.8207 - val_y1_output_loss: 1.6210 - val_y2_output_loss: 3.1880 - val_y1_output_root_mean_squared_error: 1.2674 - val_y2_output_root_mean_squared_error: 1.7928
# Epoch 76/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.1059 - y1_output_loss: 1.0850 - y2_output_loss: 3.0732 - y1_output_root_mean_squared_error: 1.0378 - y2_output_root_mean_squared_error: 1.7403 - val_loss: 20.9516 - val_y1_output_loss: 5.7875 - val_y2_output_loss: 16.8068 - val_y1_output_root_mean_squared_error: 2.3467 - val_y2_output_root_mean_squared_error: 3.9300
# Epoch 77/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.9139 - y1_output_loss: 0.9850 - y2_output_loss: 2.9225 - y1_output_root_mean_squared_error: 0.9948 - y2_output_root_mean_squared_error: 1.7101 - val_loss: 3.9214 - val_y1_output_loss: 1.6232 - val_y2_output_loss: 2.5714 - val_y1_output_root_mean_squared_error: 1.2388 - val_y2_output_root_mean_squared_error: 1.5449
# Epoch 78/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.3677 - y1_output_loss: 1.4401 - y2_output_loss: 3.9013 - y1_output_root_mean_squared_error: 1.2022 - y2_output_root_mean_squared_error: 1.9805 - val_loss: 5.3679 - val_y1_output_loss: 1.6983 - val_y2_output_loss: 3.6457 - val_y1_output_root_mean_squared_error: 1.2941 - val_y2_output_root_mean_squared_error: 1.9218
# Epoch 79/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.5849 - y1_output_loss: 1.3847 - y2_output_loss: 3.1600 - y1_output_root_mean_squared_error: 1.1809 - y2_output_root_mean_squared_error: 1.7862 - val_loss: 3.7849 - val_y1_output_loss: 1.2272 - val_y2_output_loss: 2.5698 - val_y1_output_root_mean_squared_error: 1.1142 - val_y2_output_root_mean_squared_error: 1.5948
# Epoch 80/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.3082 - y1_output_loss: 1.2031 - y2_output_loss: 3.0667 - y1_output_root_mean_squared_error: 1.1013 - y2_output_root_mean_squared_error: 1.7593 - val_loss: 5.4555 - val_y1_output_loss: 1.5148 - val_y2_output_loss: 4.3141 - val_y1_output_root_mean_squared_error: 1.2415 - val_y2_output_root_mean_squared_error: 1.9784
# Epoch 81/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.9935 - y1_output_loss: 1.1354 - y2_output_loss: 3.1476 - y1_output_root_mean_squared_error: 1.0328 - y2_output_root_mean_squared_error: 1.7108 - val_loss: 99.3896 - val_y1_output_loss: 35.8031 - val_y2_output_loss: 67.0632 - val_y1_output_root_mean_squared_error: 5.8374 - val_y2_output_root_mean_squared_error: 8.0817
# Epoch 82/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.3445 - y1_output_loss: 2.6585 - y2_output_loss: 5.6532 - y1_output_root_mean_squared_error: 1.6381 - y2_output_root_mean_squared_error: 2.3793 - val_loss: 6.7218 - val_y1_output_loss: 1.3359 - val_y2_output_loss: 5.9558 - val_y1_output_root_mean_squared_error: 1.1523 - val_y2_output_root_mean_squared_error: 2.3225
# Epoch 83/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.1401 - y1_output_loss: 2.2972 - y2_output_loss: 5.8084 - y1_output_root_mean_squared_error: 1.5167 - y2_output_root_mean_squared_error: 2.4165 - val_loss: 4.1983 - val_y1_output_loss: 1.0653 - val_y2_output_loss: 3.0811 - val_y1_output_root_mean_squared_error: 1.0249 - val_y2_output_root_mean_squared_error: 1.7742
# Epoch 84/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.3373 - y1_output_loss: 0.8195 - y2_output_loss: 2.4999 - y1_output_root_mean_squared_error: 0.9074 - y2_output_root_mean_squared_error: 1.5856 - val_loss: 4.3811 - val_y1_output_loss: 1.3249 - val_y2_output_loss: 3.4859 - val_y1_output_root_mean_squared_error: 1.1273 - val_y2_output_root_mean_squared_error: 1.7636
# Epoch 85/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.3528 - y1_output_loss: 1.0217 - y2_output_loss: 3.2974 - y1_output_root_mean_squared_error: 1.0144 - y2_output_root_mean_squared_error: 1.8231 - val_loss: 4.0448 - val_y1_output_loss: 1.1003 - val_y2_output_loss: 3.3979 - val_y1_output_root_mean_squared_error: 1.0429 - val_y2_output_root_mean_squared_error: 1.7197
# Epoch 86/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.9074 - y1_output_loss: 0.8127 - y2_output_loss: 2.1421 - y1_output_root_mean_squared_error: 0.8999 - y2_output_root_mean_squared_error: 1.4483 - val_loss: 7.1552 - val_y1_output_loss: 1.0484 - val_y2_output_loss: 6.9351 - val_y1_output_root_mean_squared_error: 1.0099 - val_y2_output_root_mean_squared_error: 2.4769
# Epoch 87/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.0976 - y1_output_loss: 0.7437 - y2_output_loss: 2.3383 - y1_output_root_mean_squared_error: 0.8616 - y2_output_root_mean_squared_error: 1.5347 - val_loss: 2.7680 - val_y1_output_loss: 0.8726 - val_y2_output_loss: 2.0150 - val_y1_output_root_mean_squared_error: 0.9395 - val_y2_output_root_mean_squared_error: 1.3730
# Epoch 88/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.8334 - y1_output_loss: 1.1547 - y2_output_loss: 3.6403 - y1_output_root_mean_squared_error: 1.0786 - y2_output_root_mean_squared_error: 1.9157 - val_loss: 5.1962 - val_y1_output_loss: 1.8800 - val_y2_output_loss: 3.6898 - val_y1_output_root_mean_squared_error: 1.3773 - val_y2_output_root_mean_squared_error: 1.8164
# Epoch 89/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.2469 - y1_output_loss: 1.0839 - y2_output_loss: 3.1357 - y1_output_root_mean_squared_error: 1.0450 - y2_output_root_mean_squared_error: 1.7762 - val_loss: 6.8197 - val_y1_output_loss: 1.6491 - val_y2_output_loss: 5.7161 - val_y1_output_root_mean_squared_error: 1.2772 - val_y2_output_root_mean_squared_error: 2.2778
# Epoch 90/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.4139 - y1_output_loss: 0.8155 - y2_output_loss: 2.5712 - y1_output_root_mean_squared_error: 0.9068 - y2_output_root_mean_squared_error: 1.6098 - val_loss: 3.6653 - val_y1_output_loss: 1.1366 - val_y2_output_loss: 2.7259 - val_y1_output_root_mean_squared_error: 1.0734 - val_y2_output_root_mean_squared_error: 1.5853
# Epoch 91/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.4772 - y1_output_loss: 1.2495 - y2_output_loss: 3.1889 - y1_output_root_mean_squared_error: 1.1221 - y2_output_root_mean_squared_error: 1.7939 - val_loss: 2.3947 - val_y1_output_loss: 0.7457 - val_y2_output_loss: 1.7747 - val_y1_output_root_mean_squared_error: 0.8609 - val_y2_output_root_mean_squared_error: 1.2859
# Epoch 92/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.3529 - y1_output_loss: 1.2471 - y2_output_loss: 3.0797 - y1_output_root_mean_squared_error: 1.1192 - y2_output_root_mean_squared_error: 1.7608 - val_loss: 2.6018 - val_y1_output_loss: 0.7476 - val_y2_output_loss: 2.1263 - val_y1_output_root_mean_squared_error: 0.8530 - val_y2_output_root_mean_squared_error: 1.3690
# Epoch 93/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.4416 - y1_output_loss: 1.1328 - y2_output_loss: 3.2856 - y1_output_root_mean_squared_error: 1.0655 - y2_output_root_mean_squared_error: 1.8183 - val_loss: 3.1748 - val_y1_output_loss: 1.0253 - val_y2_output_loss: 2.3060 - val_y1_output_root_mean_squared_error: 1.0198 - val_y2_output_root_mean_squared_error: 1.4611
# Epoch 94/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.7399 - y1_output_loss: 0.7098 - y2_output_loss: 2.0548 - y1_output_root_mean_squared_error: 0.8380 - y2_output_root_mean_squared_error: 1.4275 - val_loss: 15.7004 - val_y1_output_loss: 5.1830 - val_y2_output_loss: 12.3080 - val_y1_output_root_mean_squared_error: 2.1803 - val_y2_output_root_mean_squared_error: 3.3085
# Epoch 95/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.1035 - y1_output_loss: 0.7475 - y2_output_loss: 2.3703 - y1_output_root_mean_squared_error: 0.8667 - y2_output_root_mean_squared_error: 1.5337 - val_loss: 2.3908 - val_y1_output_loss: 0.6319 - val_y2_output_loss: 1.8672 - val_y1_output_root_mean_squared_error: 0.7951 - val_y2_output_root_mean_squared_error: 1.3261
# Epoch 96/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.2700 - y1_output_loss: 0.5304 - y2_output_loss: 1.7523 - y1_output_root_mean_squared_error: 0.7253 - y2_output_root_mean_squared_error: 1.3206 - val_loss: 3.5702 - val_y1_output_loss: 1.3344 - val_y2_output_loss: 2.3087 - val_y1_output_root_mean_squared_error: 1.1450 - val_y2_output_root_mean_squared_error: 1.5031
# Epoch 97/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.6675 - y1_output_loss: 0.6957 - y2_output_loss: 2.0107 - y1_output_root_mean_squared_error: 0.8299 - y2_output_root_mean_squared_error: 1.4067 - val_loss: 7.9514 - val_y1_output_loss: 3.4822 - val_y2_output_loss: 4.5652 - val_y1_output_root_mean_squared_error: 1.8356 - val_y2_output_root_mean_squared_error: 2.1406
# Epoch 98/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.8905 - y1_output_loss: 0.9454 - y2_output_loss: 2.9999 - y1_output_root_mean_squared_error: 0.9735 - y2_output_root_mean_squared_error: 1.7155 - val_loss: 9.6918 - val_y1_output_loss: 1.6084 - val_y2_output_loss: 8.1603 - val_y1_output_root_mean_squared_error: 1.2436 - val_y2_output_root_mean_squared_error: 2.8540
# Epoch 99/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.5569 - y1_output_loss: 0.7597 - y2_output_loss: 2.7790 - y1_output_root_mean_squared_error: 0.8707 - y2_output_root_mean_squared_error: 1.6730 - val_loss: 6.2651 - val_y1_output_loss: 1.2907 - val_y2_output_loss: 5.3447 - val_y1_output_root_mean_squared_error: 1.1392 - val_y2_output_root_mean_squared_error: 2.2287
# Epoch 100/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.1020 - y1_output_loss: 0.8731 - y2_output_loss: 3.2433 - y1_output_root_mean_squared_error: 0.9370 - y2_output_root_mean_squared_error: 1.7956 - val_loss: 11.8563 - val_y1_output_loss: 1.7326 - val_y2_output_loss: 11.1481 - val_y1_output_root_mean_squared_error: 1.3088 - val_y2_output_root_mean_squared_error: 3.1848
# Epoch 101/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.3261 - y1_output_loss: 0.8847 - y2_output_loss: 2.4132 - y1_output_root_mean_squared_error: 0.9445 - y2_output_root_mean_squared_error: 1.5601 - val_loss: 2.4153 - val_y1_output_loss: 0.7260 - val_y2_output_loss: 1.8930 - val_y1_output_root_mean_squared_error: 0.8520 - val_y2_output_root_mean_squared_error: 1.2997
# Epoch 102/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.2647 - y1_output_loss: 0.5348 - y2_output_loss: 1.7318 - y1_output_root_mean_squared_error: 0.7295 - y2_output_root_mean_squared_error: 1.3163 - val_loss: 3.3989 - val_y1_output_loss: 0.9427 - val_y2_output_loss: 2.5866 - val_y1_output_root_mean_squared_error: 0.9777 - val_y2_output_root_mean_squared_error: 1.5630
# Epoch 103/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.4290 - y1_output_loss: 0.5979 - y2_output_loss: 1.8148 - y1_output_root_mean_squared_error: 0.7758 - y2_output_root_mean_squared_error: 1.3517 - val_loss: 2.9919 - val_y1_output_loss: 0.9722 - val_y2_output_loss: 2.3023 - val_y1_output_root_mean_squared_error: 0.9770 - val_y2_output_root_mean_squared_error: 1.4274
# Epoch 104/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.4352 - y1_output_loss: 0.5695 - y2_output_loss: 1.8587 - y1_output_root_mean_squared_error: 0.7564 - y2_output_root_mean_squared_error: 1.3649 - val_loss: 2.3089 - val_y1_output_loss: 0.7498 - val_y2_output_loss: 1.7088 - val_y1_output_root_mean_squared_error: 0.8555 - val_y2_output_root_mean_squared_error: 1.2558
# Epoch 105/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.5669 - y1_output_loss: 0.9918 - y2_output_loss: 2.5631 - y1_output_root_mean_squared_error: 0.9932 - y2_output_root_mean_squared_error: 1.6064 - val_loss: 4.1020 - val_y1_output_loss: 1.9771 - val_y2_output_loss: 2.6313 - val_y1_output_root_mean_squared_error: 1.3475 - val_y2_output_root_mean_squared_error: 1.5120
# Epoch 106/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.0915 - y1_output_loss: 0.7886 - y2_output_loss: 2.2885 - y1_output_root_mean_squared_error: 0.8921 - y2_output_root_mean_squared_error: 1.5152 - val_loss: 4.7754 - val_y1_output_loss: 0.6535 - val_y2_output_loss: 4.5491 - val_y1_output_root_mean_squared_error: 0.8147 - val_y2_output_root_mean_squared_error: 2.0277
# Epoch 107/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.6651 - y1_output_loss: 0.9315 - y2_output_loss: 2.7462 - y1_output_root_mean_squared_error: 0.9660 - y2_output_root_mean_squared_error: 1.6528 - val_loss: 5.7029 - val_y1_output_loss: 0.8850 - val_y2_output_loss: 5.4181 - val_y1_output_root_mean_squared_error: 0.9414 - val_y2_output_root_mean_squared_error: 2.1947
# Epoch 108/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.3487 - y1_output_loss: 0.6910 - y2_output_loss: 1.6423 - y1_output_root_mean_squared_error: 0.8310 - y2_output_root_mean_squared_error: 1.2877 - val_loss: 2.1378 - val_y1_output_loss: 0.6569 - val_y2_output_loss: 1.5548 - val_y1_output_root_mean_squared_error: 0.8000 - val_y2_output_root_mean_squared_error: 1.2239
# Epoch 109/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.2382 - y1_output_loss: 0.5360 - y2_output_loss: 1.7135 - y1_output_root_mean_squared_error: 0.7288 - y2_output_root_mean_squared_error: 1.3066 - val_loss: 7.4265 - val_y1_output_loss: 2.0173 - val_y2_output_loss: 5.5120 - val_y1_output_root_mean_squared_error: 1.3941 - val_y2_output_root_mean_squared_error: 2.3416
# Epoch 110/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.4489 - y1_output_loss: 1.0510 - y2_output_loss: 2.3658 - y1_output_root_mean_squared_error: 1.0302 - y2_output_root_mean_squared_error: 1.5452 - val_loss: 2.2965 - val_y1_output_loss: 0.5320 - val_y2_output_loss: 2.0124 - val_y1_output_root_mean_squared_error: 0.7254 - val_y2_output_root_mean_squared_error: 1.3305
# Epoch 111/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.7718 - y1_output_loss: 0.6913 - y2_output_loss: 2.1609 - y1_output_root_mean_squared_error: 0.8291 - y2_output_root_mean_squared_error: 1.4437 - val_loss: 10.7769 - val_y1_output_loss: 1.3872 - val_y2_output_loss: 10.6128 - val_y1_output_root_mean_squared_error: 1.1633 - val_y2_output_root_mean_squared_error: 3.0698
# Epoch 112/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.3130 - y1_output_loss: 0.5177 - y2_output_loss: 1.7894 - y1_output_root_mean_squared_error: 0.7208 - y2_output_root_mean_squared_error: 1.3392 - val_loss: 3.1096 - val_y1_output_loss: 0.5854 - val_y2_output_loss: 2.8118 - val_y1_output_root_mean_squared_error: 0.7699 - val_y2_output_root_mean_squared_error: 1.5865
# Epoch 113/500
# 614/614 [==============================] - 0s 128us/sample - loss: 1.9675 - y1_output_loss: 0.4911 - y2_output_loss: 1.4581 - y1_output_root_mean_squared_error: 0.7041 - y2_output_root_mean_squared_error: 1.2132 - val_loss: 1.8513 - val_y1_output_loss: 0.5201 - val_y2_output_loss: 1.4800 - val_y1_output_root_mean_squared_error: 0.7195 - val_y2_output_root_mean_squared_error: 1.1548
# Epoch 114/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.5505 - y1_output_loss: 0.6728 - y2_output_loss: 1.8843 - y1_output_root_mean_squared_error: 0.8171 - y2_output_root_mean_squared_error: 1.3722 - val_loss: 2.0516 - val_y1_output_loss: 0.6450 - val_y2_output_loss: 1.6603 - val_y1_output_root_mean_squared_error: 0.7741 - val_y2_output_root_mean_squared_error: 1.2051
# Epoch 115/500
# 614/614 [==============================] - 0s 174us/sample - loss: 2.1811 - y1_output_loss: 0.5717 - y2_output_loss: 1.5915 - y1_output_root_mean_squared_error: 0.7595 - y2_output_root_mean_squared_error: 1.2666 - val_loss: 2.1477 - val_y1_output_loss: 0.5802 - val_y2_output_loss: 1.9326 - val_y1_output_root_mean_squared_error: 0.7315 - val_y2_output_root_mean_squared_error: 1.2699
# Epoch 116/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.5131 - y1_output_loss: 0.8924 - y2_output_loss: 2.7549 - y1_output_root_mean_squared_error: 0.9362 - y2_output_root_mean_squared_error: 1.6238 - val_loss: 9.6244 - val_y1_output_loss: 2.3754 - val_y2_output_loss: 7.8199 - val_y1_output_root_mean_squared_error: 1.5352 - val_y2_output_root_mean_squared_error: 2.6958
# Epoch 117/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.8457 - y1_output_loss: 0.6950 - y2_output_loss: 2.1546 - y1_output_root_mean_squared_error: 0.8354 - y2_output_root_mean_squared_error: 1.4655 - val_loss: 3.0754 - val_y1_output_loss: 0.5707 - val_y2_output_loss: 2.8347 - val_y1_output_root_mean_squared_error: 0.7441 - val_y2_output_root_mean_squared_error: 1.5880
# Epoch 118/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.3722 - y1_output_loss: 0.6664 - y2_output_loss: 1.6896 - y1_output_root_mean_squared_error: 0.8180 - y2_output_root_mean_squared_error: 1.3050 - val_loss: 2.1964 - val_y1_output_loss: 0.5586 - val_y2_output_loss: 1.9598 - val_y1_output_root_mean_squared_error: 0.7289 - val_y2_output_root_mean_squared_error: 1.2904
# Epoch 119/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.3377 - y1_output_loss: 1.3191 - y2_output_loss: 4.0204 - y1_output_root_mean_squared_error: 1.1509 - y2_output_root_mean_squared_error: 2.0032 - val_loss: 3.4422 - val_y1_output_loss: 1.5481 - val_y2_output_loss: 2.2150 - val_y1_output_root_mean_squared_error: 1.2172 - val_y2_output_root_mean_squared_error: 1.4002
# Epoch 120/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.1794 - y1_output_loss: 0.4707 - y2_output_loss: 1.7215 - y1_output_root_mean_squared_error: 0.6829 - y2_output_root_mean_squared_error: 1.3088 - val_loss: 3.2367 - val_y1_output_loss: 0.5769 - val_y2_output_loss: 3.0730 - val_y1_output_root_mean_squared_error: 0.7465 - val_y2_output_root_mean_squared_error: 1.6369
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3235 - y1_output_loss: 0.1150 - y2_output_loss: 0.2126 - y1_output_root_mean_squared_error: 0.3315 - y2_output_root_mean_squared_error: 0.4622 - val_loss: 1.0898 - val_y1_output_loss: 0.4326 - val_y2_output_loss: 0.7172 - val_y1_output_root_mean_squared_error: 0.6487 - val_y2_output_root_mean_squared_error: 0.8179
# Epoch 462/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.9345 - y1_output_loss: 0.2975 - y2_output_loss: 0.6378 - y1_output_root_mean_squared_error: 0.5434 - y2_output_root_mean_squared_error: 0.7995 - val_loss: 1.2002 - val_y1_output_loss: 0.2799 - val_y2_output_loss: 1.1037 - val_y1_output_root_mean_squared_error: 0.5149 - val_y2_output_root_mean_squared_error: 0.9670
# Epoch 463/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5017 - y1_output_loss: 0.1526 - y2_output_loss: 0.3477 - y1_output_root_mean_squared_error: 0.3918 - y2_output_root_mean_squared_error: 0.5901 - val_loss: 0.9397 - val_y1_output_loss: 0.2138 - val_y2_output_loss: 0.7773 - val_y1_output_root_mean_squared_error: 0.4482 - val_y2_output_root_mean_squared_error: 0.8595
# Epoch 464/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4161 - y1_output_loss: 0.1304 - y2_output_loss: 0.2832 - y1_output_root_mean_squared_error: 0.3626 - y2_output_root_mean_squared_error: 0.5335 - val_loss: 0.9056 - val_y1_output_loss: 0.1952 - val_y2_output_loss: 0.8655 - val_y1_output_root_mean_squared_error: 0.4208 - val_y2_output_root_mean_squared_error: 0.8536
# Epoch 465/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3873 - y1_output_loss: 0.1291 - y2_output_loss: 0.2552 - y1_output_root_mean_squared_error: 0.3608 - y2_output_root_mean_squared_error: 0.5071 - val_loss: 0.7692 - val_y1_output_loss: 0.2113 - val_y2_output_loss: 0.6630 - val_y1_output_root_mean_squared_error: 0.4358 - val_y2_output_root_mean_squared_error: 0.7611
# Epoch 466/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4869 - y1_output_loss: 0.1406 - y2_output_loss: 0.3434 - y1_output_root_mean_squared_error: 0.3762 - y2_output_root_mean_squared_error: 0.5877 - val_loss: 0.9796 - val_y1_output_loss: 0.1998 - val_y2_output_loss: 0.8142 - val_y1_output_root_mean_squared_error: 0.4358 - val_y2_output_root_mean_squared_error: 0.8887
# Epoch 467/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4267 - y1_output_loss: 0.1441 - y2_output_loss: 0.2829 - y1_output_root_mean_squared_error: 0.3796 - y2_output_root_mean_squared_error: 0.5316 - val_loss: 0.9287 - val_y1_output_loss: 0.1891 - val_y2_output_loss: 0.9056 - val_y1_output_root_mean_squared_error: 0.4190 - val_y2_output_root_mean_squared_error: 0.8678
# Epoch 468/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3455 - y1_output_loss: 0.1243 - y2_output_loss: 0.2185 - y1_output_root_mean_squared_error: 0.3538 - y2_output_root_mean_squared_error: 0.4695 - val_loss: 0.9429 - val_y1_output_loss: 0.2683 - val_y2_output_loss: 0.7162 - val_y1_output_root_mean_squared_error: 0.5141 - val_y2_output_root_mean_squared_error: 0.8238
# Epoch 469/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.2941 - y1_output_loss: 0.1082 - y2_output_loss: 0.1845 - y1_output_root_mean_squared_error: 0.3293 - y2_output_root_mean_squared_error: 0.4309 - val_loss: 0.7563 - val_y1_output_loss: 0.2015 - val_y2_output_loss: 0.6383 - val_y1_output_root_mean_squared_error: 0.4321 - val_y2_output_root_mean_squared_error: 0.7547
# Epoch 470/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3013 - y1_output_loss: 0.1102 - y2_output_loss: 0.1903 - y1_output_root_mean_squared_error: 0.3327 - y2_output_root_mean_squared_error: 0.4366 - val_loss: 0.9010 - val_y1_output_loss: 0.2243 - val_y2_output_loss: 0.7318 - val_y1_output_root_mean_squared_error: 0.4617 - val_y2_output_root_mean_squared_error: 0.8293
# Epoch 471/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3806 - y1_output_loss: 0.1315 - y2_output_loss: 0.2474 - y1_output_root_mean_squared_error: 0.3625 - y2_output_root_mean_squared_error: 0.4992 - val_loss: 0.8735 - val_y1_output_loss: 0.2324 - val_y2_output_loss: 0.7043 - val_y1_output_root_mean_squared_error: 0.4682 - val_y2_output_root_mean_squared_error: 0.8088
# Epoch 472/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.5202 - y1_output_loss: 0.1715 - y2_output_loss: 0.3445 - y1_output_root_mean_squared_error: 0.4158 - y2_output_root_mean_squared_error: 0.5893 - val_loss: 0.7393 - val_y1_output_loss: 0.1895 - val_y2_output_loss: 0.6366 - val_y1_output_root_mean_squared_error: 0.4182 - val_y2_output_root_mean_squared_error: 0.7512
# Epoch 473/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3368 - y1_output_loss: 0.1162 - y2_output_loss: 0.2203 - y1_output_root_mean_squared_error: 0.3401 - y2_output_root_mean_squared_error: 0.4702 - val_loss: 0.9241 - val_y1_output_loss: 0.3136 - val_y2_output_loss: 0.6966 - val_y1_output_root_mean_squared_error: 0.5435 - val_y2_output_root_mean_squared_error: 0.7929
# Epoch 474/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3330 - y1_output_loss: 0.1198 - y2_output_loss: 0.2118 - y1_output_root_mean_squared_error: 0.3471 - y2_output_root_mean_squared_error: 0.4610 - val_loss: 0.9347 - val_y1_output_loss: 0.2447 - val_y2_output_loss: 0.7375 - val_y1_output_root_mean_squared_error: 0.4839 - val_y2_output_root_mean_squared_error: 0.8370
# Epoch 475/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4967 - y1_output_loss: 0.1457 - y2_output_loss: 0.3527 - y1_output_root_mean_squared_error: 0.3810 - y2_output_root_mean_squared_error: 0.5928 - val_loss: 1.3251 - val_y1_output_loss: 0.3858 - val_y2_output_loss: 1.0042 - val_y1_output_root_mean_squared_error: 0.6126 - val_y2_output_root_mean_squared_error: 0.9746
# Epoch 476/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3719 - y1_output_loss: 0.1189 - y2_output_loss: 0.2506 - y1_output_root_mean_squared_error: 0.3452 - y2_output_root_mean_squared_error: 0.5028 - val_loss: 0.9323 - val_y1_output_loss: 0.2515 - val_y2_output_loss: 0.7819 - val_y1_output_root_mean_squared_error: 0.4841 - val_y2_output_root_mean_squared_error: 0.8354
# Epoch 477/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3430 - y1_output_loss: 0.1141 - y2_output_loss: 0.2273 - y1_output_root_mean_squared_error: 0.3385 - y2_output_root_mean_squared_error: 0.4779 - val_loss: 0.7798 - val_y1_output_loss: 0.1961 - val_y2_output_loss: 0.6711 - val_y1_output_root_mean_squared_error: 0.4247 - val_y2_output_root_mean_squared_error: 0.7742
# Epoch 478/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4276 - y1_output_loss: 0.1342 - y2_output_loss: 0.2913 - y1_output_root_mean_squared_error: 0.3661 - y2_output_root_mean_squared_error: 0.5418 - val_loss: 0.8165 - val_y1_output_loss: 0.1973 - val_y2_output_loss: 0.7129 - val_y1_output_root_mean_squared_error: 0.4233 - val_y2_output_root_mean_squared_error: 0.7983
# Epoch 479/500
# 614/614 [==============================] - 0s 179us/sample - loss: 0.4505 - y1_output_loss: 0.1590 - y2_output_loss: 0.2890 - y1_output_root_mean_squared_error: 0.4001 - y2_output_root_mean_squared_error: 0.5389 - val_loss: 0.7635 - val_y1_output_loss: 0.1990 - val_y2_output_loss: 0.6592 - val_y1_output_root_mean_squared_error: 0.4304 - val_y2_output_root_mean_squared_error: 0.7604
# Epoch 480/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3913 - y1_output_loss: 0.1290 - y2_output_loss: 0.2606 - y1_output_root_mean_squared_error: 0.3607 - y2_output_root_mean_squared_error: 0.5111 - val_loss: 0.7567 - val_y1_output_loss: 0.1920 - val_y2_output_loss: 0.6416 - val_y1_output_root_mean_squared_error: 0.4224 - val_y2_output_root_mean_squared_error: 0.7604
# Epoch 481/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3108 - y1_output_loss: 0.1111 - y2_output_loss: 0.1976 - y1_output_root_mean_squared_error: 0.3345 - y2_output_root_mean_squared_error: 0.4460 - val_loss: 0.8187 - val_y1_output_loss: 0.2182 - val_y2_output_loss: 0.6779 - val_y1_output_root_mean_squared_error: 0.4498 - val_y2_output_root_mean_squared_error: 0.7851
# Epoch 482/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3151 - y1_output_loss: 0.1142 - y2_output_loss: 0.2016 - y1_output_root_mean_squared_error: 0.3376 - y2_output_root_mean_squared_error: 0.4485 - val_loss: 0.8134 - val_y1_output_loss: 0.1787 - val_y2_output_loss: 0.7450 - val_y1_output_root_mean_squared_error: 0.4071 - val_y2_output_root_mean_squared_error: 0.8048
# Epoch 483/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4568 - y1_output_loss: 0.1399 - y2_output_loss: 0.3132 - y1_output_root_mean_squared_error: 0.3756 - y2_output_root_mean_squared_error: 0.5619 - val_loss: 0.9882 - val_y1_output_loss: 0.2571 - val_y2_output_loss: 0.7793 - val_y1_output_root_mean_squared_error: 0.4969 - val_y2_output_root_mean_squared_error: 0.8610
# Epoch 484/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4039 - y1_output_loss: 0.1300 - y2_output_loss: 0.2705 - y1_output_root_mean_squared_error: 0.3620 - y2_output_root_mean_squared_error: 0.5223 - val_loss: 0.7925 - val_y1_output_loss: 0.2282 - val_y2_output_loss: 0.6639 - val_y1_output_root_mean_squared_error: 0.4579 - val_y2_output_root_mean_squared_error: 0.7634
# Epoch 485/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.6396 - y1_output_loss: 0.1621 - y2_output_loss: 0.4749 - y1_output_root_mean_squared_error: 0.4042 - y2_output_root_mean_squared_error: 0.6900 - val_loss: 0.9075 - val_y1_output_loss: 0.2198 - val_y2_output_loss: 0.8163 - val_y1_output_root_mean_squared_error: 0.4523 - val_y2_output_root_mean_squared_error: 0.8384
# Epoch 486/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4472 - y1_output_loss: 0.1586 - y2_output_loss: 0.2882 - y1_output_root_mean_squared_error: 0.3980 - y2_output_root_mean_squared_error: 0.5374 - val_loss: 1.0827 - val_y1_output_loss: 0.3344 - val_y2_output_loss: 0.8271 - val_y1_output_root_mean_squared_error: 0.5631 - val_y2_output_root_mean_squared_error: 0.8750
# Epoch 487/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3468 - y1_output_loss: 0.1200 - y2_output_loss: 0.2263 - y1_output_root_mean_squared_error: 0.3462 - y2_output_root_mean_squared_error: 0.4765 - val_loss: 0.7750 - val_y1_output_loss: 0.2004 - val_y2_output_loss: 0.6370 - val_y1_output_root_mean_squared_error: 0.4354 - val_y2_output_root_mean_squared_error: 0.7651
# Epoch 488/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3415 - y1_output_loss: 0.1089 - y2_output_loss: 0.2316 - y1_output_root_mean_squared_error: 0.3305 - y2_output_root_mean_squared_error: 0.4820 - val_loss: 0.8416 - val_y1_output_loss: 0.2160 - val_y2_output_loss: 0.7411 - val_y1_output_root_mean_squared_error: 0.4443 - val_y2_output_root_mean_squared_error: 0.8026
# Epoch 489/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3306 - y1_output_loss: 0.1133 - y2_output_loss: 0.2193 - y1_output_root_mean_squared_error: 0.3363 - y2_output_root_mean_squared_error: 0.4663 - val_loss: 0.8771 - val_y1_output_loss: 0.2271 - val_y2_output_loss: 0.7894 - val_y1_output_root_mean_squared_error: 0.4608 - val_y2_output_root_mean_squared_error: 0.8153
# Epoch 490/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3963 - y1_output_loss: 0.1531 - y2_output_loss: 0.2414 - y1_output_root_mean_squared_error: 0.3911 - y2_output_root_mean_squared_error: 0.4933 - val_loss: 0.8375 - val_y1_output_loss: 0.2965 - val_y2_output_loss: 0.6817 - val_y1_output_root_mean_squared_error: 0.5125 - val_y2_output_root_mean_squared_error: 0.7581
# Epoch 491/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3507 - y1_output_loss: 0.1184 - y2_output_loss: 0.2297 - y1_output_root_mean_squared_error: 0.3454 - y2_output_root_mean_squared_error: 0.4811 - val_loss: 0.8490 - val_y1_output_loss: 0.2352 - val_y2_output_loss: 0.7539 - val_y1_output_root_mean_squared_error: 0.4584 - val_y2_output_root_mean_squared_error: 0.7993
# Epoch 492/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4084 - y1_output_loss: 0.1247 - y2_output_loss: 0.2807 - y1_output_root_mean_squared_error: 0.3537 - y2_output_root_mean_squared_error: 0.5323 - val_loss: 0.8029 - val_y1_output_loss: 0.2235 - val_y2_output_loss: 0.6558 - val_y1_output_root_mean_squared_error: 0.4635 - val_y2_output_root_mean_squared_error: 0.7669
# Epoch 493/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4125 - y1_output_loss: 0.1292 - y2_output_loss: 0.2809 - y1_output_root_mean_squared_error: 0.3611 - y2_output_root_mean_squared_error: 0.5311 - val_loss: 1.0633 - val_y1_output_loss: 0.2058 - val_y2_output_loss: 0.8765 - val_y1_output_root_mean_squared_error: 0.4455 - val_y2_output_root_mean_squared_error: 0.9300
# Epoch 494/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4099 - y1_output_loss: 0.1346 - y2_output_loss: 0.2752 - y1_output_root_mean_squared_error: 0.3673 - y2_output_root_mean_squared_error: 0.5244 - val_loss: 1.0566 - val_y1_output_loss: 0.2408 - val_y2_output_loss: 0.8568 - val_y1_output_root_mean_squared_error: 0.4765 - val_y2_output_root_mean_squared_error: 0.9108
# Epoch 495/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.2944 - y1_output_loss: 0.1145 - y2_output_loss: 0.1778 - y1_output_root_mean_squared_error: 0.3397 - y2_output_root_mean_squared_error: 0.4231 - val_loss: 0.7547 - val_y1_output_loss: 0.2036 - val_y2_output_loss: 0.6108 - val_y1_output_root_mean_squared_error: 0.4406 - val_y2_output_root_mean_squared_error: 0.7487
# Epoch 496/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4198 - y1_output_loss: 0.1197 - y2_output_loss: 0.3045 - y1_output_root_mean_squared_error: 0.3431 - y2_output_root_mean_squared_error: 0.5496 - val_loss: 1.0786 - val_y1_output_loss: 0.4416 - val_y2_output_loss: 0.7962 - val_y1_output_root_mean_squared_error: 0.6332 - val_y2_output_root_mean_squared_error: 0.8232
# Epoch 497/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4202 - y1_output_loss: 0.1421 - y2_output_loss: 0.2775 - y1_output_root_mean_squared_error: 0.3772 - y2_output_root_mean_squared_error: 0.5272 - val_loss: 1.0015 - val_y1_output_loss: 0.3344 - val_y2_output_loss: 0.7900 - val_y1_output_root_mean_squared_error: 0.5524 - val_y2_output_root_mean_squared_error: 0.8344
# Epoch 498/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3867 - y1_output_loss: 0.1255 - y2_output_loss: 0.2601 - y1_output_root_mean_squared_error: 0.3548 - y2_output_root_mean_squared_error: 0.5107 - val_loss: 0.7758 - val_y1_output_loss: 0.1965 - val_y2_output_loss: 0.6667 - val_y1_output_root_mean_squared_error: 0.4256 - val_y2_output_root_mean_squared_error: 0.7711
# Epoch 499/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3319 - y1_output_loss: 0.1230 - y2_output_loss: 0.2116 - y1_output_root_mean_squared_error: 0.3498 - y2_output_root_mean_squared_error: 0.4577 - val_loss: 1.1885 - val_y1_output_loss: 0.2805 - val_y2_output_loss: 1.1076 - val_y1_output_root_mean_squared_error: 0.5048 - val_y2_output_root_mean_squared_error: 0.9663
# Epoch 500/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4507 - y1_output_loss: 0.1423 - y2_output_loss: 0.3063 - y1_output_root_mean_squared_error: 0.3778 - y2_output_root_mean_squared_error: 0.5550 - val_loss: 0.8382 - val_y1_output_loss: 0.2408 - val_y2_output_loss: 0.7376 - val_y1_output_root_mean_squared_error: 0.4644 - val_y2_output_root_mean_squared_error: 0.7890

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 332us/sample - loss: 0.8382 - y1_output_loss: 0.2199 - y2_output_loss: 0.6387 - y1_output_root_mean_squared_error: 0.4644 - y2_output_root_mean_squared_error: 0.7890
# Loss = 0.8382345112887296, Y1_loss = 0.21985983848571777, Y1_mse = 0.4643663763999939, Y2_loss = 0.6387394070625305, Y2_mse = 0.7890490293502808

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
